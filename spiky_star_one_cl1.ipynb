# %% [markdown]
# <a href="https://colab.research.google.com/github/kerron3000/spiky-star-one/blob/main/spiky_star_one_cl1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Learning Statements

# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# ##Variables

# %%
var = 1

# %%
x =1
y =2

z = x+y

print ("Value if z is ", z)
# Out:
# Value if z is  3

# %% [markdown]
# ###Data Structures

# %% [markdown]
# ####List

# %%
my_list = [1,2,3]

# %%
my_list [1] ##value will be 2
# Out:
# 2

# %% [markdown]
# ####Dictionary

# %%
my_dict = {1:"one", 2:"two"}

# %%
type (my_dict)
# Out:
# dict

# %%
my_dict.keys()
# Out:
# dict_keys([1, 2])

# %%
my_dict.values()
# Out:
# dict_values(['one', 'two'])

# %% [markdown]
# ##Loops

# %%
for k,v in my_dict.items():
  print(f"This is my key: {k}")
  print (f"This is my value: {v}")
# Out:
# This is my key: 1
# This is my value: one
# This is my key: 2
# This is my value: two

# %%
for i in my_list:
  print (f"This is the value in the list: {i}")
# Out:
# This is the value in the list: 1
# This is the value in the list: 2
# This is the value in the list: 3
